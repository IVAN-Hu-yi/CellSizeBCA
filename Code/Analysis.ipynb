# %%
# %matplotlib inline
import numpy as np
from scipy.integrate import solve_ivp
from parametres import Paras
from utilities import *
from initialisation import *
from odes import odes_scale_size
import matplotlib.pyplot as plt
from size_scaled_func import *
import datetime as dt
from simulation_func import *
import pandas as pd
import pickle as pkl
import os

# %% [markdown]
# # Loading Data

# %% [markdown]
# - Load data from `Data`

# %%
base_dir = '..\Data'
sample_number = 1
t_type = '_t.npy'
Para_type ='_Para.pkl'
Rt_type = '_Rt.npy'
Ct_type = '_Ct.npy'
file_name = f'\Abl_{sample_number}'

# %%
# start loading
repr_t = np.load(base_dir + file_name + file_name + t_type)
repr_Rt = np.load(base_dir + file_name + file_name + Rt_type)
repr_Ct = np.load(base_dir + file_name + file_name + Ct_type)
para = pkl.load(open(base_dir + file_name + file_name + Para_type, 'rb'))

# %% [markdown]
# # Visualise population trajectories
#
# - Starts with absolute biomass
# - Then Abundance

# %%
# plot species biomass trajectories
plt.figure(figsize=(6, 6), dpi=300)
for i in range(para.M):
    sns.lineplot(x=repr_t, y=repr_Rt[i, :])
plt.xlabel('Time')
plt.ylabel('Resource content')
sns.despine(offset=10, trim=True)

# %%
# plot species biomass trajectories
np.seterr(divide = 'ignore')
plt.figure(figsize=(6, 6), dpi=300)
for i in range(para.N):
    sns.lineplot(x=np.log10(repr_t), y=repr_Ct[i, :], color='grey', alpha=0.3)
plt.xlabel('Time')
plt.ylabel('Absolute biomass')
sns.despine(offset=10, trim=True)

# %%
# plot species abudance trajectories
np.seterr(divide = 'ignore')
plt.figure(figsize=(6, 6), dpi=300)
for i in range(para.N):
    sns.lineplot(x=np.log10(repr_t), y=relative_abundance(repr_Ct)[i, :]*100,color='grey', alpha=0.3)
plt.xlabel('Time')
plt.ylabel('relative abundance (%)')
sns.despine(offset=10, trim=True)
